# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)][def]
#
# [def]: https://colab.research.google.com/github/LEE-Sanghoon/CSE1017/blob/main/chap05-선택문.ipynb

# %% [markdown]
# # Chapter 05 선택문

# %% [markdown]
# ### if 문

# %% [markdown]
# [예제 5-1] 입력받은 양수가 홀수 또는 짝수인지 확인하기
#
# ```C
# #include <stdio.h>
#
# int main(void)
# {
#     int input;
#     printf("양수를 입력하세요.\n");
#     scanf("%d", &input);
#
#     if (input%2 == 0)
#         printf("입력한 수 %d는 짝수입니다.\n", input);
#     else
#         printf("입력한 수 %d는 홀수입니다.\n", input);
#
#     return 0;
# }
# ```

# %%
# %%writefile ex5_1.c
# #include <stdio.h>
#
# int main(void)
# {
#     int input;
#     printf("양수를 입력하세요.\n");
#     scanf("%d", &input);
#
#     if (input%2 == 0)
#         printf("입력한 수 %d는 짝수입니다.\n", input);
#     else
#         printf("입력한 수 %d는 홀수입니다.\n", input);
#
#     return 0;
# }
# Out:
# Overwriting ex5_1.c

# %%
# !gcc ex5_1.c -o ex5_1

# %%
# !./ex5_1
# Out:
# 양수를 입력하세요.
# 10
# 입력한 수 10는 짝수입니다.

# %% [markdown]
# ### if ~ else if 문

# %% [markdown]
# [예제 5-2] 성적을 입력받아 학점 출력하기
# ```C
# #include <stdio.h>
#
# int main(void)
# {
#     int jumsu;
#
#     printf("0점에서 100점 사이의 점수를 입력하세요.\n");
#     scanf("%d", &jumsu);
#
#     if(jumsu >= 0 && jumsu <= 100)
#         printf("입력한 점수는 %d점입니다.\n", jumsu);
#     else
#     {
#         printf("0점에서 100점 사이를 입력하셔야 합니다.\n");
#         return 0;
#     }
#
#     if(jumsu >= 0 && jumsu < 60)
#         printf("%d점은 F학점입니다.\n", jumsu);
#
#     else if(jumsu >= 60 && jumsu < 70)
#         printf("%d점은 D학점입니다.\n", jumsu);
#
#     else if(jumsu >= 70 && jumsu < 80)
#         printf("%d점은 C학점입니다.\n", jumsu);
#
#     else if(jumsu >= 80 && jumsu < 90)
#         printf("%d점은 B학점입니다.\n", jumsu);
#
#     else if(jumsu >= 90 && jumsu < 100)
#         printf("%d점은 A학점입니다.\n", jumsu);
#
#     return 0;
# }
# ```

# %%
# %%writefile ex5_2.c

# %%
# !gcc ex5_2.c

# %%
# !./a.out

# %% [markdown]
# ### 다중 if문

# %% [markdown]
# [예제 5-3] 다중 if문 사용하기
#
# ```C
# #include <stdio.h>
#
# int main(void)
# {
#     int input;
#     printf("양수를 입력하세요.\n");
#     scanf("%d", &input);
#
#     if(input >= 0)
#     {
#         if(input%2 == 0)
#             printf("입력한 수 %d은 짝수입니다.\n", input);
#         else
#             printf("입력한 수 %d은 홀수입니다.\n", input);
#     }
#     else
#     {
#         printf("입력한 수 %d은 음수입니다.\n", input);
#     }
#
#     return 0;
# }
# ```

# %%
# %%writefile ex5_3.c

# %% [markdown]
# [예제 5-4] 다중 if문 사용하지 않기
#
# ```C
# #include <stdio.h>
#
# int main(void)
# {
#     int input;
#     printf("양수를 입력하세요.\n");
#     scanf("%d", &input);
#
#     if( input >= 0 && input % 2 == 0)
#         printf("입력한 수 %d은 양수이며 짝수입니다.\n", input);
#
#     else if( input >= 0 && input % 2 !=0)
#         printf("입력한 수 %d은 홀수입니다.\n", input);
#
#     else
#         printf("입력한 수 %d은 음수입니다.\n", input);
#
#     return 0;
# }
# ```

# %%
# %%writefile ex5_4.c

# %% [markdown]
# [예제 5-5] switch ~ case 문 사용하기
#
# ```C
# #include <stdio.h>
#
# int main(void)
# {
#     int input;
#
#     printf("영어로 인사하는 법을 배우겠습니다.\n");
#     printf("아침 인사는 1번을 누르세요.\n");
#     printf("점심 인사는 2번을 누르세요.\n");
#     printf("저녁 인사는 3번을 누르세요.\n");
#     scanf("%d", &input);
#
#     switch(input) {
#         case 1:
#             printf("Good Morning!!\n");
#             break;
#         case 2:
#             printf("Good Afternoon!!\n");
#             break;
#         case 3:
#             printf("Good Night!!\n");
#             break;
#     }
#
#     return 0;
# }
# ```

# %%
# %%writefile ex5_5.c

# %% [markdown]
# [예제 5-6] default를 사용하여 예외 처리하기
#
# ```C
# #include <stdio.h>
#
# int main(void)
# {
#     int input;
#
#     printf("영어로 인사하는 법을 배우겠습니다.\n");
#     printf("아침 인사는 1번을 누르세요.\n");
#     printf("점심 인사는 2번을 누르세요.\n");
#     printf("저녁 인사는 3번을 누르세요.\n");
#     scanf("%d", &input);
#
#     switch(input) {
#         case 1:
#             printf("Good Morning!!\n");
#             break;
#         case 2:
#             printf("Good Afternoon!!\n");
#             break;
#         case 3:
#             printf("Good Night!!\n");
#             break;
#         default:
#             printf("잘못 입력했습니다. 1~3 사이의 숫자를 입력하세요.\n");
#     }
#
#     return 0;
# }
# ```

# %%
# %%writefile ex5_6.c

# %% [markdown]
# [예제 5-7] switch 문의 조건으로 수식 사용하기
#
# ```C
# #include <stdio.h>
#
# int main(void)
# {
#     int score;
#
#     printf("당신의 점수를 입력하세요 :");
#     scanf("%d", &score);
#
#     switch(score/10)
#     {
#         case 10:
#         case 9: printf("점수는 %d점이고 성적은 %c입니다.\n", score, 'A'); break;
#
#         case 8: printf("점수는 %d점이고 성적은 %c입니다.\n", score, 'B'); break;
#
#         case 7: printf("점수는 %d점이고 성적은 %c입니다.\n", score, 'C'); break;
#
#         case 6: printf("점수는 %d점이고 성적은 %c입니다.\n", score, 'D'); break;
#
#         default: printf("점수는 %d점이고 성적은 %c입니다.\n", score, 'F'); break;
#     }
#
#     return 0;
# }
# ```

# %%
# %%writefile ex5_7.c

# %% [markdown]
# [예제 5-8] break 문의 잘못된 사용
#
# ```C
# #include <stdio.h>
#
# int main(void)
# {
#     int input;
#
#     printf("영어로 인사하는 법을 배우겠습니다.\n");
#     printf("아침 인사는 1번을 누르세요.\n");
#     printf("점심 인사는 2번을 누르세요.\n");
#     printf("저녁 인사는 3번을 누르세요.\n");
#     scanf("%d", &input);
#
#     switch(input) {
#         case 1:
#             printf("Good Morning!!\n");
#             /* break; */
#         case 2:
#             printf("Good Afternoon!!\n");
#             // break;
#         case 3:
#             printf("Good Night!!\n");
#             break;
#         default:
#             printf("잘못 입력했습니다. 1~3 사이의 숫자를 입력하세요.\n");
#     }
#
#     return 0;
# }
# ```

# %%
# %%writefile ex5_8.c

# %% [markdown]
# [예제 5-9] break문 적절하게 사용하기
#
# ```C
# #include <stdio.h>
#
# int main(void)
# {
#     int input;
#     printf("평점이 4.2 이상 4.3 미만이면 1번을 누르세요.\n");
#     printf("평점이 4.3 이상 4.4 미만이면 2번을 누르세요.\n");
#     printf("평점이 4.4 이상이면 3번을 누르세요.\n");
#     scanf("%d", &input);
#
#     switch(input)
#     {
#         case 3:
#             printf("해외 연수 기회가 주어집니다.\n");
#         case 2:
#             printf("장학금을 받습니다.\n");
#         case 1:
#             printf("겨울 특강 수강 자격을 받습니다.\n");
#             break;
#         default:
#             printf("잘못 입력했습니다. 1~3 사이의 숫자를 입력하세요.\n");
#     }
#
#     return 0;
# }
# ```

# %%
# %%writefile ex5_9.c

# %% [markdown]
# ### if 문과 switch~case 문의 대응 관계

# %% [markdown]
# [예제 5-10] switch 문을 이용한 사칙연산
#
# ```C
# #include <stdio.h>
#
# int main(void)
# {
#     int num1, num2;
#     char arithmetic;
#
#     printf("숫자 2개와 연산자를 입력하세요.\n\n");
#
#     printf("연산자는 아래와 같습니다.\n");
#     printf("더하기: +, 빼기: -, 곱하기: *, 나누기: /\n");
#     printf("입력 순서: 정수1 연산자 정수2\n\n");
#     scanf("%d %c %d", &num1, &arithmetic, &num2);
#
#     switch(arithmetic)
#     {
#         case '+':
#             printf("%d %c %d = %d \n", num1, arithmetic, num2, num1 + num2);
#             break;
#
#         case '-':
#             printf("%d %c %d = %d \n", num1, arithmetic, num2, num1 - num2);
#             break;
#
#         case '*':
#             printf("%d %c %d = %d \n", num1, arithmetic, num2, num1 * num2);
#             break;
#
#         case '/':
#             printf("%d %c %d = %d \n", num1, arithmetic, num2, num1 / num2);
#             break;
#
#         default:
#             printf("연산자를 잘못 입력했습니다.\n");
#             break;
#     }
#
#     return 0;
# }
# ```

# %%
# %%writefile ex5_10.c

# %% [markdown]
# [예제 5-11] if~else if 문을 이용한 사칙연산
#
# ```C
# #include <stdio.h>
#
# int main(void)
# {
#     int num1, num2;
#     char arithmetic;
#
#     printf("숫자 2개와 연산자를 입력하세요.\n\n");
#
#     printf("연산자는 아래와 같습니다.\n");
#     printf("더하기: +, 빼기: -, 곱하기: *, 나누기: /\n");
#     printf("입력 순서: 정수1 연산자 정수2\n\n");
#     scanf("%d %c %d", &num1, &arithmetic, &num2);
#
#     if (arithmetic == '+')
#         printf("%d %c %d = %d \n", num1, arithmetic, num2, num1 + num2);
#
#     else if (arithmetic == '-')
#         printf("%d %c %d = %d \n", num1, arithmetic, num2, num1 - num2);
#
#     else if (arithmetic == '*')
#         printf("%d %c %d = %d \n", num1, arithmetic, num2, num1 * num2);
#
#     else if (arithmetic =='/')
#         printf("%d %c %d = %d \n", num1, arithmetic, num2, num1 / num2);
#
#     else
#         printf("연산자를 잘못 입력했습니다.\n");
#
#     return 0;
# }
# ```

# %%
# %%writefile ex5_11.c

# %% [markdown]
# ### 조건 연산자

# %% [markdown]
# [예제 5-12]
#
# ```C
# #include <stdio.h>
#
# int main(void)
# {
#     int min, max;
#
#     int x = 10, y = 20;
#
#     max = ( x > y ) ? x : y;
#     min = ( x > y ) ? y : x;
#
#     printf("두 수 %d와 %d 중에 큰 수는 %d이다.\n", x, y, max);
#     printf("두 수 %d와 %d 중에 작은 수는 %d이다.\n", x, y, min);
#
#     return 0;
# }
# ```

# %%
# %%writefile ex5_12.c

# %% [markdown]
# [예제 5-13] 조건 연산자를 이용하여 유횻값 확인하기
#
# ```C
# #include <stdio.h>
#
# int main(void)
# {
#     int x;
#
#     printf("양수를 입력하세요.\n");
#     scanf("%d", &x);
#
#     ( x >= 0 ) ? printf("x는 유효한 값입니다.\n") : printf("y는 유효한 값이 아닙니다.\n");
#
#     return 0;
# }
# ```

# %%
# %%writefile ex5_13.c

# %% [markdown]
# [예제 5-14] if 문을 이용하여 큰 값과 작은 값 구하기
#
# ```C
# #include <stdio.h>
#
# int main(void)
# {
#     int min, max;
#     int x, y;
#
#     printf("숫자 2개를 입력하세요.\n");
#     scanf("%d %d", &x, &y);
#
#     if (x > y)
#     {
#         max = x;
#         min = y;
#     }
#     else
#     {
#         max = y;
#         min = x;
#     }
#
#     printf("두 수 %d와 %d 중 큰 수는 %d이다.\n", x, y, max);
#     printf("두 수 %d와 %d 중 작은 수는 %d이다.\n", x, y, min);
#
#
#     return 0;
# }
# ```

# %%
# %%writefile ex5_14.c

# %% [markdown]
# ---
# ## 연습문제

# %% [markdown]
# ### 5-3:
#
# 조건 연산자로 작성된 다음 프로그램을 if문을 이용한 프로그램으로 바꾸시오.
#
# ```C
# int value, x;
# scanf("%d", &x);
# value = x > 0 ? 1 : 0;
#
# int answer = 20, x;
# scanf("%d", &x);
# (answer == x) ? printf("정답\n") : printf("오답\n");

# %%
# %%writefile exercise5_3.c

# %% [markdown]
# ### 5-4:
#
# 임의의 양의 정수를 입력받아 2 또는 3 또는 5의 배수인지 확인하는 프로그램을 작성하시오.

# %%
# %%writefile exercise5_4.c

# %% [markdown]
# ### 5-5:
#
# 제시한 조건에 맞게 프로그램을 작성하시오.
#
# 1. 정수 3개를 입력받아 3개 수 중에서 최댓값을 구하는 프로그램을 제어문을 이용하여 작성하시오.
#
# 2. 1번에서 작성한 프로그램을 조건 연산자를 이용한 프로그램으로 바꾸시오.
#
# 3. 정수 3개를 입력받아 3개의 수 중에서 중간값을 구하는 프로그램을 제어문을 이용하여 작성하시오.
#
# 4. 3번에서 작성한 프로그램을 조건 연산자를 이용한 프로그램으로 바꾸시오.

# %%
# %%writefile exercise5_5_1.c

# %%
# %%writefile exercise5_5_2.c

# %%
# %%writefile exercise5_5_3.c

# %%
# %%writefile exercise5_5_4.c

# %% [markdown]
# ### 5-6:
#
# if~else if문을 이용하여 정삼각형, 정사각형, 원의 넓이를 선택적으로 구하는 프로그램을 작성하시오. 이때 어떤 도형의 넓이를 구할지와 선택된 도형에 따른 한 변의 길이 또는 반지름을 사용자에게 입력받는다.

# %%
# %%writefile exercise5_6.c

# %% [markdown]
# ### 5-7:
#
# switch~case문을 이용하여 달(month)을 입력받고 그 달에 며칠(day)이 있는지 출력하는 프로그램을 작성하시오. 이때 날수가 같은 달에는 break문을 사용하지 않고 프로그램을 작성하시오(단, 2월은 29일까지 있다고 가정한다).

# %%
# %%writefile exercise5_7.c
